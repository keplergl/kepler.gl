# %%
with open('geojson-data.json', 'r') as f:
    geojson = f.read()
    print geojson
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "fill": true
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               2.331032753,
#               48.8411359942
#             ],
#             [
#               2.3269987106,
#               48.8425764529
#             ],
#             [
#               2.3253250122,
#               48.8431130838
#             ],
#             [
#               2.3240375519,
#               48.8435367357
#             ],
#             [
#               2.3217630386,
#               48.8443840288
#             ],
#             [
#               2.3203468323,
#               48.8448923977
#             ],
#             [
#               2.3189735413,
#               48.8453160346
#             ],
#             [
#               2.3167848587,
#               48.846558682
#             ],
#             [
#               2.3136520386,
#               48.8456831836
#             ],
#             [
#               2.3111844063,
#               48.8450618529
#             ],
#             [
#               2.3070859909,
#               48.8438897762
#             ],
#             [
#               2.2969740629,
#               48.8408994443
#             ],
#             [
#               2.2952359915,
#               48.8427106112
#             ],
#             [
#               2.2949945927,
#               48.84285183
#             ],
#             [
#               2.2928863764,
#               48.8436249961
#             ],
#             [
#               2.2912180424,
#               48.844327543
#             ],
#             [
#               2.2873932123,
#               48.8458173336
#             ],
#             [
#               2.2863632441,
#               48.8462833253
#             ],
#             [
#               2.2854137421,
#               48.8467704938
#             ],
#             [
#               2.2820448875,
#               48.849008584
#             ],
#             [
#               2.2804355621,
#               48.8498063649
#             ],
#             [
#               2.2793841362,
#               48.8498204848
#             ],
#             [
#               2.2790408134,
#               48.8506535519
#             ],
#             [
#               2.2756505013,
#               48.8526585039
#             ],
#             [
#               2.2742128372,
#               48.8531667889
#             ],
#             [
#               2.2726249695,
#               48.8535197615
#             ],
#             [
#               2.2703289986,
#               48.8542539366
#             ],
#             [
#               2.2671747208,
#               48.8551434035
#             ],
#             [
#               2.2649002075,
#               48.855694018
#             ],
#             [
#               2.2637414932,
#               48.8544233601
#             ],
#             [
#               2.2617030144,
#               48.8551010483
#             ],
#             [
#               2.2633981705,
#               48.8576564152
#             ],
#             [
#               2.2649002075,
#               48.8599434285
#             ],
#             [
#               2.2664451599,
#               48.8626538275
#             ],
#             [
#               2.2666811943,
#               48.8631902432
#             ],
#             [
#               2.267947197,
#               48.8647006461
#             ],
#             [
#               2.2694063187,
#               48.8667897264
#             ],
#             [
#               2.2713589668,
#               48.8690480934
#             ],
#             [
#               2.2736120224,
#               48.871009967
#             ],
#             [
#               2.2753071785,
#               48.8723507717
#             ],
#             [
#               2.2773456573,
#               48.8737197667
#             ],
#             [
#               2.2782897949,
#               48.8750040476
#             ],
#             [
#               2.2804999352,
#               48.8774737258
#             ],
#             [
#               2.2818946838,
#               48.8795058267
#             ],
#             [
#               2.2835040092,
#               48.8808605148
#             ],
#             [
#               2.2857570648,
#               48.882229277
#             ],
#             [
#               2.2899627686,
#               48.8848396989
#             ],
#             [
#               2.2913146019,
#               48.8857568418
#             ],
#             [
#               2.294511795,
#               48.8876475141
#             ],
#             [
#               2.2955846786,
#               48.8878732613
#             ],
#             [
#               2.2964859009,
#               48.8878027154
#             ],
#             [
#               2.297065258,
#               48.8876192956
#             ],
#             [
#               2.2975587845,
#               48.8874923124
#             ],
#             [
#               2.298116684,
#               48.8875064216
#             ],
#             [
#               2.298438549,
#               48.8875910772
#             ],
#             [
#               2.2989320755,
#               48.8879296979
#             ],
#             [
#               2.2997903824,
#               48.8882965344
#             ],
#             [
#               2.3006701469,
#               48.8886210414
#             ],
#             [
#               2.3015713692,
#               48.889270049
#             ],
#             [
#               2.3037815094,
#               48.8903423041
#             ],
#             [
#               2.3057985306,
#               48.8900742425
#             ],
#             [
#               2.3074293137,
#               48.8893405928
#             ],
#             [
#               2.3093390465,
#               48.8887762396
#             ],
#             [
#               2.311205864,
#               48.8880566801
#             ],
#             [
#               2.314145565,
#               48.8876051864
#             ],
#             [
#               2.3184370995,
#               48.8917954552
#             ],
#             [
#               2.3220419884,
#               48.8897497449
#             ],
#             [
#               2.325668335,
#               48.887703951
#             ],
#             [
#               2.3268485069,
#               48.8851924481
#             ],
#             [
#               2.3274922371,
#               48.8838378774
#             ],
#             [
#               2.328063794,
#               48.883946667
#             ],
#             [
#               2.329651662,
#               48.88493438
#             ],
#             [
#               2.336046047,
#               48.88318471
#             ],
#             [
#               2.339479275,
#               48.882422738
#             ],
#             [
#               2.342912503,
#               48.882987163
#             ],
#             [
#               2.345744913,
#               48.883551581
#             ],
#             [
#               2.34951366,
#               48.884013132
#             ],
#             [
#               2.35071529,
#               48.882827858
#             ],
#             [
#               2.351959835,
#               48.881501444
#             ],
#             [
#               2.352954691,
#               48.880503646
#             ],
#             [
#               2.354234348,
#               48.8790743
#             ],
#             [
#               2.355393062,
#               48.877752921
#             ],
#             [
#               2.35625137,
#               48.876623947
#             ],
#             [
#               2.3603439331,
#               48.8759495959
#             ],
#             [
#               2.3634767532,
#               48.875413317
#             ],
#             [
#               2.3630905151,
#               48.8741996118
#             ],
#             [
#               2.3636484146,
#               48.8733528233
#             ],
#             [
#               2.3643350601,
#               48.8725060204
#             ],
#             [
#               2.3652791977,
#               48.8711511061
#             ],
#             [
#               2.3658370972,
#               48.8704171788
#             ],
#             [
#               2.3668670654,
#               48.8691468946
#             ],
#             [
#               2.3678970337,
#               48.8694432972
#             ],
#             [
#               2.3685836792,
#               48.8686105428
#             ],
#             [
#               2.368991375,
#               48.8680459556
#             ],
#             [
#               2.3677682877,
#               48.8677636597
#             ],
#             [
#               2.3687553406,
#               48.8666626902
#             ],
#             [
#               2.3702573776,
#               48.8647994559
#             ],
#             [
#               2.371544838,
#               48.8632184755
#             ],
#             [
#               2.3724031448,
#               48.8618350766
#             ],
#             [
#               2.3724031448,
#               48.8604516395
#             ],
#             [
#               2.3719739914,
#               48.8594634467
#             ],
#             [
#               2.371544838,
#               48.8586164088
#             ],
#             [
#               2.3711585999,
#               48.8575434736
#             ],
#             [
#               2.3706436157,
#               48.8566681672
#             ],
#             [
#               2.3701715469,
#               48.8555951902
#             ],
#             [
#               2.3698282242,
#               48.8546916128
#             ],
#             [
#               2.3700428009,
#               48.8529126471
#             ],
#             [
#               2.3684120178,
#               48.8526302657
#             ],
#             [
#               2.3662662506,
#               48.8520654983
#             ],
#             [
#               2.3646354675,
#               48.8515007245
#             ],
#             [
#               2.3644798994,
#               48.8514583662
#             ],
#             [
#               2.3643136024,
#               48.8514195377
#             ],
#             [
#               2.3640614748,
#               48.8513312911
#             ],
#             [
#               2.3639059067,
#               48.8512854028
#             ],
#             [
#               2.3637878895,
#               48.8512395145
#             ],
#             [
#               2.3636591434,
#               48.8511759767
#             ],
#             [
#               2.3634928465,
#               48.8511159687
#             ],
#             [
#               2.363294363,
#               48.8510594905
#             ],
#             [
#               2.3630422354,
#               48.8509888927
#             ],
#             [
#               2.3628437519,
#               48.8509394742
#             ],
#             [
#               2.3625648022,
#               48.8507806287
#             ],
#             [
#               2.3624360561,
#               48.8507100305
#             ],
#             [
#               2.3620980978,
#               48.8506641416
#             ],
#             [
#               2.3619157076,
#               48.8506394322
#             ],
#             [
#               2.3615992069,
#               48.8506217826
#             ],
#             [
#               2.361395359,
#               48.8505829535
#             ],
#             [
#               2.3611968756,
#               48.8505441243
#             ],
#             [
#               2.3611646891,
#               48.8504982353
#             ],
#             [
#               2.361100316,
#               48.8504452864
#             ],
#             [
#               2.3609608412,
#               48.8503888075
#             ],
#             [
#               2.3608535528,
#               48.8503287985
#             ],
#             [
#               2.3607730865,
#               48.8502970291
#             ],
#             [
#               2.3605155945,
#               48.8502299602
#             ],
#             [
#               2.360419035,
#               48.8501805409
#             ],
#             [
#               2.3603439331,
#               48.8501523013
#             ],
#             [
#               2.3601508141,
#               48.8500287529
#             ],
#             [
#               2.3589706421,
#               48.8495804459
#             ],
#             [
#               2.3583698273,
#               48.8491850853
#             ],
#             [
#               2.365322113,
#               48.8442710572
#             ],
#             [
#               2.3629188538,
#               48.8400909296
#             ],
#             [
#               2.3513317108,
#               48.8363624133
#             ],
#             [
#               2.3368692398,
#               48.8393000554
#             ],
#             [
#               2.3351955414,
#               48.8398367214
#             ],
#             [
#               2.3342084885,
#               48.8402039106
#             ],
#             [
#               2.3331356049,
#               48.8405146071
#             ],
#             [
#               2.331032753,
#               48.8411359942
#             ]
#           ]
#         ]
#       }
#     }
#   ]
# }

# %%
import keplergl
map_1 = keplergl.KeplerGl(height=600)
map_1
# Out:
# User Guide: https://github.com/keplergl/kepler.gl/blob/master/docs/keplergl-jupyter/user-guide.md
# KeplerGl(height=600)

# %%
map_1.add_data(geojson, "geojson")

# %%
map_1.save_to_html(file_name="geojson_map.html")
# Out:
# geojson_map.html
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-b5d72a09ca54> in <module>()
# ----> 1 map_1.save_to_html("geojson_map.html")
#
# /Users/shanhe/Uber/kepler.gl/bindings/kepler.gl-jupyter/keplergl/keplergl.py in save_to_html(self, data, config, file_name, read_only)
#     158         k = keplergl_html.find("<body>")
#     159
# --> 160         data_to_add = self.data if data == None else data_to_json(data, None)
#     161         config_to_add = self.config if config == None else config
#     162
#
# /Users/shanhe/Uber/kepler.gl/bindings/kepler.gl-jupyter/keplergl/keplergl.py in data_to_json(data, manager)
#      55         if type(data) is not dict:
#      56             print data
# ---> 57             raise Exception('data type incorrect expecting a dictionary mapping from data id to value, but got {}'.format(type(data)))
#      58             return None
#      59         else:
#
# Exception: data type incorrect expecting a dictionary mapping from data id to value, but got <type 'str'>
